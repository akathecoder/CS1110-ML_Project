# %% [markdown]
# # **1.Importing Libraries**

# %%
import os 
import pandas as pd
import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import seaborn as sns
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, BatchNormalization, MaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169
import cv2

# %% [markdown]
# # **2. Creating datasets**

# %%
def generate_dataset_from_directory(folder_path, size = 224,batch_size = 32): 

    image_generator = ImageDataGenerator(
        samplewise_center=True, #Set each sample mean to 0.
        samplewise_std_normalization= True, # Divide each input by its standard deviation]
        #rescale=1./255,
        validation_split = 0.3
    )

    #create training and testing datasets
    train_data = image_generator.flow_from_directory(directory = 
        folder_path,
        class_mode="categorical",
        color_mode="rgb",
        target_size = (size, size),
        batch_size  = batch_size,
        shuffle=True,
        seed=123,
        subset="training"
    )

    #create training and testing datasets
    val_data = image_generator.flow_from_directory(directory = 
        folder_path,
        class_mode="categorical",
        color_mode="rgb",
        target_size = (size, size),
        batch_size  = batch_size,
        shuffle=True,
        seed=123,
        subset="validation"
    )

    return train_data, val_data

# %%
folder_path = '../input/covid19-radiography-database/COVID-19_Radiography_Dataset/'
train_data, val_data = generate_dataset_from_directory(
    folder_path, size = 128,batch_size = 32)
# Out:
# Found 14818 images belonging to 4 classes.
# Found 6347 images belonging to 4 classes.

# %% [markdown]
# # **3.Exploratory Data Analysis**

# %%
class_names = train_data.class_indices
print(class_names)
# Out:
# {'COVID': 0, 'Lung_Opacity': 1, 'Normal': 2, 'Viral Pneumonia': 3}

# %%
classes = list(class_names.keys())
print(classes)
# Out:
# ['COVID', 'Lung_Opacity', 'Normal', 'Viral Pneumonia']

# %%
images,labels = next(train_data)
labels = np.argmax(labels, axis=1)
class_dict = train_data.class_indices
class_dict_inv = dict((v, k) for k, v in class_dict.items())
y_names = [class_dict_inv[key] for key in labels]

# %%
#Lets visualize the augmented images
plt.figure(figsize=(10, 10))
for image in images:
    j  = 0
    for i in range(4):
        ax = plt.subplot(1, 4, i+1)
        for k in range(len(labels)):
            if labels[k] == j:
                plt.imshow(images[k])
                plt.title(classes[i])
                plt.axis("off")
                break
        j = j+1

# %%
# Investing single image
raw_image = images[k]
plt.imshow(raw_image, cmap='gray')
plt.colorbar()
plt.title('Raw Chest X Ray Image')
print(f"The dimensions of the image are {raw_image.shape[0]} pixels width and {raw_image.shape[1]} pixels height, one single color channel")
print(f"The maximum pixel value is {raw_image.max():.4f} and the minimum is {raw_image.min():.4f}")
print(f"The mean value of the pixels is {raw_image.mean():.4f} and the standard deviation is {raw_image.std():.4f}")
# Out:
# The dimensions of the image are 128 pixels width and 128 pixels height, one single color channel
# The maximum pixel value is 1.4452 and the minimum is -3.0251
# The mean value of the pixels is 0.0000 and the standard deviation is 1.0000

# %%
# Plot a histogram of the distribution of the pixels
sns.distplot(raw_image.ravel(), 
             label=f'Pixel Mean {np.mean(raw_image):.4f} & Standard Deviation {np.std(raw_image):.4f}', kde=False)
plt.legend(loc='upper center')
plt.title('Distribution of Pixel Intensities in the Image')
plt.xlabel('Pixel Intensity')
plt.ylabel('# Pixels in Image')
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, '# Pixels in Image')

# %%
all_items,dirs,files = next(os.walk(folder_path))

# %%
image_in_classes = []
for i in range(len(dirs)):
    no_of_images =len(os.listdir(os.path.join(folder_path,dirs[i])))
    image_in_classes.append(no_of_images)
df_data = {'class': dirs,'counts': image_in_classes}
classes_df = pd.DataFrame(df_data)

# %%
sns.barplot(x = 'class', y = 'counts',data = classes_df)
plt.title('Class counts')
plt.show()

# %% [markdown]
# # **4. Predictive Modeling**

# %%
def plotLearningCurve(history,epochs):
  epochRange = range(1,epochs+1)
  fig, ax = plt.subplots(1,2,figsize=(20,10))
  ax[0].plot(epochRange,history.history['accuracy'],'b',label = 'Training Accuracy')
  ax[0].plot(epochRange,history.history['val_accuracy'],'r',label = 'Validation Accuracy')
  ax[0].set_title('Training and Validation accuracy')
  ax[0].set_xlabel('Epoch', fontsize = 20)
  ax[0].set_ylabel('Accuracy', fontsize = 20)
  ax[0].legend()
  ax[0].grid(color='gray', linestyle='--')
  ax[1].plot(epochRange,history.history['loss'],'b',label = 'Training Loss')
  ax[1].plot(epochRange,history.history['val_loss'],'r',label = 'Validation Loss')
  ax[1].set_title('Training and Validation loss')
  ax[1].set_xlabel('Epoch', fontsize = 20)
  ax[1].set_ylabel('Loss', fontsize = 20)
  ax[1].legend()
  ax[1].grid(color='gray', linestyle='--')
  plt.show()

# %% [markdown]
# ### Using Resnet

# %%
def resnet_model(train_data,test_data, epochs,size):
#Building the model using Keras functional API
    print("----Building the model----")
    
    base_model = ResNet50(input_shape= (size,size,3), include_top=False)
#     base_model.trainable=False #freezing the layer


    x=base_model.output
    x=GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    out=Dense(4,activation='softmax')(x)

    model=Model(inputs=base_model.input,outputs=out) 
    # model.summary()
#Training the Convolutional Neural Network
    print("----Training the network----")
    model.compile(optimizer= Adam(0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    
    early_stop = EarlyStopping(monitor='val_loss', 
                               mode='min', 
                               patience = 5 ,
                               restore_best_weights=True)
    #model_checkpoint
    mc = ModelCheckpoint('resnet_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
    r = model.fit(train_data, 
                  validation_data = val_data, 
                  epochs = epochs, 
                  verbose = 2,
                  batch_size = 32,
                  callbacks = [early_stop,mc])
    print("Train score:", model.evaluate(train_data))
    print("Test score:", model.evaluate(val_data))
    n_epochs = len(r.history['loss'])
    
    return r,model,n_epochs

# %%
epochs = 10
r,model,n_epochs = resnet_model(train_data, val_data,epochs,128)
# Out:
# ----Building the model----
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# ----Training the network----
# Epoch 1/10
# 464/464 - 128s - loss: 0.3142 - accuracy: 0.8845 - val_loss: 1.4328 - val_accuracy: 0.5767
#
# Epoch 00001: val_loss improved from inf to 1.43281, saving model to resnet_model.h5
# Epoch 2/10
# 464/464 - 63s - loss: 0.1521 - accuracy: 0.9448 - val_loss: 0.3584 - val_accuracy: 0.8933
#
# Epoch 00002: val_loss improved from 1.43281 to 0.35839, saving model to resnet_model.h5
# Epoch 3/10
# 464/464 - 63s - loss: 0.1002 - accuracy: 0.9634 - val_loss: 0.2289 - val_accuracy: 0.9294
#
# Epoch 00003: val_loss improved from 0.35839 to 0.22888, saving model to resnet_model.h5
# Epoch 4/10
# 464/464 - 62s - loss: 0.0701 - accuracy: 0.9760 - val_loss: 0.2114 - val_accuracy: 0.9349
#
# Epoch 00004: val_loss improved from 0.22888 to 0.21143, saving model to resnet_model.h5
# Epoch 5/10
# 464/464 - 62s - loss: 0.0451 - accuracy: 0.9852 - val_loss: 0.4249 - val_accuracy: 0.9039
#
# Epoch 00005: val_loss did not improve from 0.21143
# Epoch 6/10
# 464/464 - 62s - loss: 0.0547 - accuracy: 0.9814 - val_loss: 0.3042 - val_accuracy: 0.9029
#
# Epoch 00006: val_loss did not improve from 0.21143
# Epoch 7/10
# 464/464 - 62s - loss: 0.0539 - accuracy: 0.9808 - val_loss: 0.2336 - val_accuracy: 0.9373
#
# Epoch 00007: val_loss did not improve from 0.21143
# Epoch 8/10
# 464/464 - 62s - loss: 0.0309 - accuracy: 0.9899 - val_loss: 0.5448 - val_accuracy: 0.8555
#
# Epoch 00008: val_loss did not improve from 0.21143
# Epoch 9/10
# 464/464 - 62s - loss: 0.0281 - accuracy: 0.9906 - val_loss: 0.2549 - val_accuracy: 0.9346
#
# Epoch 00009: val_loss did not improve from 0.21143
# 464/464 [==============================] - 40s 87ms/step - loss: 0.0438 - accuracy: 0.9866
# Train score: [0.043758612126111984, 0.9865703582763672]
# 199/199 [==============================] - 17s 86ms/step - loss: 0.2114 - accuracy: 0.9349
# Test score: [0.21142564713954926, 0.9349299073219299]

# %%
plotLearningCurve(r,n_epochs)

# %%
# printing model accuracy for train and test data
test_evaluation = model.evaluate(val_data)
print(f"Test Accuracy using ResNet50: {test_evaluation[1] * 100:.2f}%")

train_evaluation = model.evaluate(train_data)
print(f"Train Accuracy using ResNet50: {train_evaluation[1] * 100:.2f}%")
# Out:
# 199/199 [==============================] - 17s 86ms/step - loss: 0.2114 - accuracy: 0.9349
# Test Accuracy using ResNet50: 93.49%
# 464/464 [==============================] - 40s 86ms/step - loss: 0.0438 - accuracy: 0.9866
# Train Accuracy using ResNet50: 98.66%

# %% [markdown]
# ###
