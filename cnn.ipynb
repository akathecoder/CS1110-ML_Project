# %% [markdown]
# # **1.Importing Libraries**

# %%
import os 
import pandas as pd
import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import seaborn as sns
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, BatchNormalization, MaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169
import cv2

# %% [markdown]
# # **2. Creating datasets**

# %%
def generate_dataset_from_directory(folder_path, size = 224,batch_size = 32): 

    image_generator = ImageDataGenerator(
        samplewise_center=True, #Set each sample mean to 0.
        samplewise_std_normalization= True, # Divide each input by its standard deviation]
        #rescale=1./255,
        validation_split = 0.3
    )

    #create training and testing datasets
    train_data = image_generator.flow_from_directory(directory = 
        folder_path,
        class_mode="categorical",
        color_mode="rgb",
        target_size = (size, size),
        batch_size  = batch_size,
        shuffle=True,
        seed=123,
        subset="training"
    )

    #create training and testing datasets
    val_data = image_generator.flow_from_directory(directory = 
        folder_path,
        class_mode="categorical",
        color_mode="rgb",
        target_size = (size, size),
        batch_size  = batch_size,
        shuffle=True,
        seed=123,
        subset="validation"
    )

    return train_data, val_data

# %%
folder_path = '../input/covid19-radiography-database/COVID-19_Radiography_Dataset/'
train_data, val_data = generate_dataset_from_directory(
    folder_path, size = 128,batch_size = 32)
# Out:
# Found 14818 images belonging to 4 classes.
# Found 6347 images belonging to 4 classes.

# %% [markdown]
# # **3.Exploratory Data Analysis**

# %%
class_names = train_data.class_indices
print(class_names)
# Out:
# {'COVID': 0, 'Lung_Opacity': 1, 'Normal': 2, 'Viral Pneumonia': 3}

# %%
classes = list(class_names.keys())
print(classes)
# Out:
# ['COVID', 'Lung_Opacity', 'Normal', 'Viral Pneumonia']

# %%
images,labels = next(train_data)
labels = np.argmax(labels, axis=1)
class_dict = train_data.class_indices
class_dict_inv = dict((v, k) for k, v in class_dict.items())
y_names = [class_dict_inv[key] for key in labels]

# %%
#Lets visualize the augmented images
plt.figure(figsize=(10, 10))
for image in images:
    j  = 0
    for i in range(4):
        ax = plt.subplot(1, 4, i+1)
        for k in range(len(labels)):
            if labels[k] == j:
                plt.imshow(images[k])
                plt.title(classes[i])
                plt.axis("off")
                break
        j = j+1

# %%
# Investing single image
raw_image = images[k]
plt.imshow(raw_image, cmap='gray')
plt.colorbar()
plt.title('Raw Chest X Ray Image')
print(f"The dimensions of the image are {raw_image.shape[0]} pixels width and {raw_image.shape[1]} pixels height, one single color channel")
print(f"The maximum pixel value is {raw_image.max():.4f} and the minimum is {raw_image.min():.4f}")
print(f"The mean value of the pixels is {raw_image.mean():.4f} and the standard deviation is {raw_image.std():.4f}")
# Out:
# The dimensions of the image are 128 pixels width and 128 pixels height, one single color channel
# The maximum pixel value is 1.4452 and the minimum is -3.0251
# The mean value of the pixels is 0.0000 and the standard deviation is 1.0000

# %%
# Plot a histogram of the distribution of the pixels
sns.distplot(raw_image.ravel(), 
             label=f'Pixel Mean {np.mean(raw_image):.4f} & Standard Deviation {np.std(raw_image):.4f}', kde=False)
plt.legend(loc='upper center')
plt.title('Distribution of Pixel Intensities in the Image')
plt.xlabel('Pixel Intensity')
plt.ylabel('# Pixels in Image')
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, '# Pixels in Image')

# %%
all_items,dirs,files = next(os.walk(folder_path))

# %%
image_in_classes = []
for i in range(len(dirs)):
    no_of_images =len(os.listdir(os.path.join(folder_path,dirs[i])))
    image_in_classes.append(no_of_images)
df_data = {'class': dirs,'counts': image_in_classes}
classes_df = pd.DataFrame(df_data)

# %%
sns.barplot(x = 'class', y = 'counts',data = classes_df)
plt.title('Class counts')
plt.show()

# %% [markdown]
# # **4. Predictive Modeling**

# %% [markdown]
# ### Using Convolutional Neural Networks

# %%
def plotLearningCurve(history,epochs):
  epochRange = range(1,epochs+1)
  fig, ax = plt.subplots(1,2,figsize=(20,10))
  ax[0].plot(epochRange,history.history['accuracy'],'b',label = 'Training Accuracy')
  ax[0].plot(epochRange,history.history['val_accuracy'],'r',label = 'Validation Accuracy')
  ax[0].set_title('Training and Validation accuracy')
  ax[0].set_xlabel('Epoch', fontsize = 20)
  ax[0].set_ylabel('Accuracy', fontsize = 20)
  ax[0].legend()
  ax[0].grid(color='gray', linestyle='--')
  ax[1].plot(epochRange,history.history['loss'],'b',label = 'Training Loss')
  ax[1].plot(epochRange,history.history['val_loss'],'r',label = 'Validation Loss')
  ax[1].set_title('Training and Validation loss')
  ax[1].set_xlabel('Epoch', fontsize = 20)
  ax[1].set_ylabel('Loss', fontsize = 20)
  ax[1].legend()
  ax[1].grid(color='gray', linestyle='--')
  plt.show()

# %%
def cnn_model(train_data,test_data, epochs,size):
#Building the model using Keras functional API
    print("----Building the model----")
    i = Input(shape=(size,size,3)) #defining input
    x = BatchNormalization()(i)
    x = Conv2D(32,3, activation= 'relu')(i) #adding convolution layers
    x = MaxPooling2D()(x)
    x = Dropout(0.2)(x)
    x = Conv2D(64, 3, activation='relu')(x)
    x = MaxPooling2D()(x)
    x = Dropout(0.2)(x)
    x = Conv2D(128, 3, activation='relu')(x)
    x = MaxPooling2D()(x)
    x = Dropout(0.2)(x)
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.1)(x)
    x = Dense(4, activation= 'softmax')(x)

    model = Model(i,x)
    model.summary()
#Training the Convolutional Neural Network
    print("----Training the network----")
    model.compile(optimizer= Adam(0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    
    early_stop = EarlyStopping(monitor='val_loss', 
                               mode='min', 
                               patience = 5 ,
                               restore_best_weights=True)
    #model_checkpoint
    mc = ModelCheckpoint('cnn_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
    r = model.fit(train_data, 
                  validation_data = val_data, 
                  epochs = epochs, 
                  verbose = 2,
                  batch_size = 32,
                  callbacks = [early_stop,mc])
    print("Train score:", model.evaluate(train_data))
    print("Test score:", model.evaluate(val_data))
    n_epochs = len(r.history['loss'])
    
    return r,model,n_epochs

# %%
epochs = 20
r,model,n_epochs = cnn_model(train_data, val_data,epochs,128)
# Out:
# ----Building the model----
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               6422784
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 6,517,060
# Trainable params: 6,517,060
# Non-trainable params: 0
# _________________________________________________________________
# ----Training the network----
# Epoch 1/20
# 464/464 - 160s - loss: 0.7552 - accuracy: 0.6973 - val_loss: 0.6198 - val_accuracy: 0.8013
#
# Epoch 00001: val_loss improved from inf to 0.61978, saving model to cnn_model.h5
# Epoch 2/20
# 464/464 - 55s - loss: 0.5573 - accuracy: 0.7842 - val_loss: 0.5347 - val_accuracy: 0.8171
#
# Epoch 00002: val_loss improved from 0.61978 to 0.53472, saving model to cnn_model.h5
# Epoch 3/20
# 464/464 - 55s - loss: 0.4751 - accuracy: 0.8190 - val_loss: 0.4589 - val_accuracy: 0.8417
#
# Epoch 00003: val_loss improved from 0.53472 to 0.45893, saving model to cnn_model.h5
# Epoch 4/20
# 464/464 - 55s - loss: 0.4182 - accuracy: 0.8428 - val_loss: 0.4159 - val_accuracy: 0.8573
#
# Epoch 00004: val_loss improved from 0.45893 to 0.41591, saving model to cnn_model.h5
# Epoch 5/20
# 464/464 - 55s - loss: 0.3690 - accuracy: 0.8635 - val_loss: 0.3881 - val_accuracy: 0.8647
#
# Epoch 00005: val_loss improved from 0.41591 to 0.38812, saving model to cnn_model.h5
# Epoch 6/20
# 464/464 - 56s - loss: 0.3317 - accuracy: 0.8758 - val_loss: 0.4383 - val_accuracy: 0.8385
#
# Epoch 00006: val_loss did not improve from 0.38812
# Epoch 7/20
# 464/464 - 55s - loss: 0.3014 - accuracy: 0.8870 - val_loss: 0.3668 - val_accuracy: 0.8659
#
# Epoch 00007: val_loss improved from 0.38812 to 0.36678, saving model to cnn_model.h5
# Epoch 8/20
# 464/464 - 55s - loss: 0.2747 - accuracy: 0.8986 - val_loss: 0.3893 - val_accuracy: 0.8602
#
# Epoch 00008: val_loss did not improve from 0.36678
# Epoch 9/20
# 464/464 - 55s - loss: 0.2464 - accuracy: 0.9101 - val_loss: 0.3917 - val_accuracy: 0.8609
#
# Epoch 00009: val_loss did not improve from 0.36678
# Epoch 10/20
# 464/464 - 54s - loss: 0.2248 - accuracy: 0.9174 - val_loss: 0.4004 - val_accuracy: 0.8645
#
# Epoch 00010: val_loss did not improve from 0.36678
# Epoch 11/20
# 464/464 - 53s - loss: 0.1995 - accuracy: 0.9252 - val_loss: 0.3579 - val_accuracy: 0.8790
#
# Epoch 00011: val_loss improved from 0.36678 to 0.35791, saving model to cnn_model.h5
# Epoch 12/20
# 464/464 - 55s - loss: 0.1815 - accuracy: 0.9322 - val_loss: 0.3949 - val_accuracy: 0.8677
#
# Epoch 00012: val_loss did not improve from 0.35791
# Epoch 13/20
# 464/464 - 56s - loss: 0.1619 - accuracy: 0.9417 - val_loss: 0.3878 - val_accuracy: 0.8768
#
# Epoch 00013: val_loss did not improve from 0.35791
# Epoch 14/20
# 464/464 - 55s - loss: 0.1471 - accuracy: 0.9463 - val_loss: 0.3957 - val_accuracy: 0.8762
#
# Epoch 00014: val_loss did not improve from 0.35791
# Epoch 15/20
# 464/464 - 55s - loss: 0.1294 - accuracy: 0.9526 - val_loss: 0.4185 - val_accuracy: 0.8683
#
# Epoch 00015: val_loss did not improve from 0.35791
# Epoch 16/20
# 464/464 - 56s - loss: 0.1170 - accuracy: 0.9571 - val_loss: 0.4187 - val_accuracy: 0.8765
#
# Epoch 00016: val_loss did not improve from 0.35791
# 464/464 [==============================] - 40s 86ms/step - loss: 0.1713 - accuracy: 0.9426
# Train score: [0.17132525146007538, 0.9426373243331909]
# 199/199 [==============================] - 17s 86ms/step - loss: 0.3579 - accuracy: 0.8790
# Test score: [0.3579147458076477, 0.8789979815483093]

# %%
plotLearningCurve(r,n_epochs)

# %%
# printing model accuracy for train and test data
test_evaluation = model.evaluate(val_data)
print(f"Test Accuracy using CNN: {test_evaluation[1] * 100:.2f}%")

train_evaluation = model.evaluate(train_data)
print(f"Train Accuracy using CNN: {train_evaluation[1] * 100:.2f}%")
# Out:
# 199/199 [==============================] - 17s 84ms/step - loss: 0.3579 - accuracy: 0.8790
# Test Accuracy using CNN: 87.90%
# 464/464 [==============================] - 40s 86ms/step - loss: 0.1713 - accuracy: 0.9426
# Train Accuracy using CNN: 94.26%

# %% [markdown]
# ###
